# %% [markdown]
# #### Hive Internal and External Tables

# %% [markdown]
# #### Create File For Demonstration

# %%
dbutils.fs.put("/FileStore/students.csv","""id,Name
1,john
2,dane
3,stallone
4,slyvester
5,steve
6,tony
7,bruce""",overwrite=True)
# Out:
# Wrote 67 bytes.
# Out[36]: True

# %%
# %fs head /FileStore/students.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">id,Name
# 1,john
# 2,dane
# 3,stallone
# 4,slyvester
# 5,steve
# 6,tony
# 7,bruce
# </div>

# %% [markdown]
# ##### Managed/Hive Tables
# - You can check the filesystem with %fs ls user/hive/warehouse/
# - you can remove the files with %fs rm -r user/hive/warehouse/sharmatrilok.db

# %%
# %sql
CREATE TABLE student(
id INT,
Name STRING)
ROW FORMAT DELIMITED
FIELDS TERMINATED BY ',';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
describe extended student;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>id</td><td>int</td><td>null</td></tr><tr><td>Name</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>student</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Created Time</td><td>Mon Dec 05 08:16:32 UTC 2022</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.2.1</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Provider</td><td>hive</td><td></td></tr><tr><td>Table Properties</td><td>[transient_lastDdlTime=1670228192]</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/hive/warehouse/student</td><td></td></tr><tr><td>Serde Library</td><td>org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe</td><td></td></tr><tr><td>InputFormat</td><td>org.apache.hadoop.mapred.TextInputFormat</td><td></td></tr><tr><td>OutputFormat</td><td>org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat</td><td></td></tr><tr><td>Storage Properties</td><td>[field.delim=,, serialization.format=,]</td><td></td></tr><tr><td>Partition Provider</td><td>Catalog</td><td></td></tr></tbody></table></div>

# %%
# %sql
LOAD DATA LOCAL INPATH 'dbfs:/FileStore/students.csv' INTO TABLE student;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from student;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>Name</th></tr></thead><tbody><tr><td>null</td><td>Name</td></tr><tr><td>1</td><td>john</td></tr><tr><td>2</td><td>dane</td></tr><tr><td>3</td><td>stallone</td></tr><tr><td>4</td><td>slyvester</td></tr><tr><td>5</td><td>steve</td></tr><tr><td>6</td><td>tony</td></tr><tr><td>7</td><td>bruce</td></tr></tbody></table></div>

# %%
# %sql
truncate table student;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from student;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>Name</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
describe extended student;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>id</td><td>int</td><td>null</td></tr><tr><td>Name</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>student</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Created Time</td><td>Mon Dec 05 08:16:32 UTC 2022</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.2.1</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Provider</td><td>hive</td><td></td></tr><tr><td>Table Properties</td><td>[transient_lastDdlTime=1670229828]</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/hive/warehouse/student</td><td></td></tr><tr><td>Serde Library</td><td>org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe</td><td></td></tr><tr><td>InputFormat</td><td>org.apache.hadoop.mapred.TextInputFormat</td><td></td></tr><tr><td>OutputFormat</td><td>org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat</td><td></td></tr><tr><td>Storage Properties</td><td>[field.delim=,, serialization.format=,]</td><td></td></tr><tr><td>Partition Provider</td><td>Catalog</td><td></td></tr></tbody></table></div>

# %%
# %sql
drop table student;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# #### External Tables

# %%
dbutils.fs.mkdirs("/FileStore/Students")

# %%
dbutils.fs.cp("/FileStore/students.csv","/FileStore/Students/")

# %%
# %sql
CREATE EXTERNAL TABLE  IF NOT EXISTS student(
id INT,
Name STRING)
ROW FORMAT DELIMITED
FIELDS TERMINATED BY ','
LOCATION 'dbfs:/FileStore/Students';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- drop table if exists student;
describe extended student;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>id</td><td>int</td><td>null</td></tr><tr><td>Name</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>student</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Created Time</td><td>Mon Dec 05 09:13:51 UTC 2022</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.2.1</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Provider</td><td>hive</td><td></td></tr><tr><td>Table Properties</td><td>[transient_lastDdlTime=1670231631]</td><td></td></tr><tr><td>Location</td><td>dbfs:/FileStore/Students</td><td></td></tr><tr><td>Serde Library</td><td>org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe</td><td></td></tr><tr><td>InputFormat</td><td>org.apache.hadoop.mapred.TextInputFormat</td><td></td></tr><tr><td>OutputFormat</td><td>org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat</td><td></td></tr><tr><td>Storage Properties</td><td>[field.delim=,, serialization.format=,]</td><td></td></tr><tr><td>Partition Provider</td><td>Catalog</td><td></td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM student;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>Name</th></tr></thead><tbody><tr><td>null</td><td>Name</td></tr><tr><td>1</td><td>john</td></tr><tr><td>2</td><td>dane</td></tr><tr><td>3</td><td>stallone</td></tr><tr><td>4</td><td>slyvester</td></tr><tr><td>5</td><td>steve</td></tr><tr><td>6</td><td>tony</td></tr><tr><td>7</td><td>bruce</td></tr><tr><td>null</td><td>null</td></tr><tr><td>101</td><td>johnson</td></tr><tr><td>102</td><td>quil</td></tr><tr><td>103</td><td>groot</td></tr></tbody></table></div>

# %%
dbutils.fs.put("/FileStore/Students/students1.csv","""
101,johnson
102,quil
103,groot
""",overwrite=True)
# Out:
# Wrote 32 bytes.
# Out[61]: True

# %%
# %sql
SELECT * FROM student;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>Name</th></tr></thead><tbody><tr><td>null</td><td>Name</td></tr><tr><td>1</td><td>john</td></tr><tr><td>2</td><td>dane</td></tr><tr><td>3</td><td>stallone</td></tr><tr><td>4</td><td>slyvester</td></tr><tr><td>5</td><td>steve</td></tr><tr><td>6</td><td>tony</td></tr><tr><td>7</td><td>bruce</td></tr><tr><td>null</td><td>null</td></tr><tr><td>101</td><td>johnson</td></tr><tr><td>102</td><td>quil</td></tr><tr><td>103</td><td>groot</td></tr></tbody></table></div>

# %%
# %sql
drop table student;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from student;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-957540864188454> in <module>
#       5     display(df)
#       6     return df
# ----> 7   _sqldf = ____databricks_percent_sql()
#       8 finally:
#       9   del ____databricks_percent_sql
#
# <command-957540864188454> in ____databricks_percent_sql()
#       2   def ____databricks_percent_sql():
#       3     import base64
# ----> 4     df = spark.sql(base64.standard_b64decode("c2VsZWN0ICogZnJvbSBzdHVkZW50").decode())
#       5     display(df)
#       6     return df
#
# /databricks/spark/python/pyspark/sql/session.py in sql(self, sqlQuery)
#     775         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     776         """
# --> 777         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     778
#     779     def table(self, tableName):
#
# /databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     121                 # Hide where the exception came from that shows a non-Pythonic
#     122                 # JVM exception message.
# --> 123                 raise converted from None
#     124             else:
#     125                 raise
#
# AnalysisException: Table or view not found: student; line 1 pos 14;
# 'Project [*]
# +- 'UnresolvedRelation [student], [], false

# %% [markdown]
# ### Spark/Hive Partitions
#
# ##### To set Any Configuration in spark session we can use
# ```python
# spark.conf.set("spark.sql.shuffle.partitions", "500")
# ./bin/spark-submit --conf spark.sql.shuffle.partitions=500 --conf spark.default.parallelism=500
#
# ```

# %% [markdown]
# #### Create Database

# %%
# %sql
CREATE DATABASE IF NOT EXISTS sharmatrilok;
USE sharmatrilok;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
drop table if exists sales; 
CREATE TABLE sales(
 InvoiceNO          int         comment 'Invoice No',
 StockCode          int         comment 'Stock Code means product Id', 
 Description        string      comment 'Description',
 Quantity           int         comment 'Quantity of a product ordered in invoice',
 InvoiceDate        timestamp   comment 'Invoice Date',
 UnitPrice          double      comment 'Unit Price',
 CustomerID         int         comment 'Customer ID'
)
PARTITIONED BY (Country string)
ROW FORMAT DELIMITED FIELDS TERMINATED BY ','
LINES TERMINATED BY '\n'
STORED AS TEXTFILE
LOCATION '/user/hive/warehouse/sharmatrilok';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
spark.conf.set("hive.exec.dynamic.partition", "true")
spark.conf.set("hive.exec.dynamic.partition.mode", "nonstrict")

# %% [markdown]
# ### Parsed Sales DATA according to Hive Table
# - Spark support 'yyyy-MM-dd HH:MM:SS' format as timestamp.
# - Need to convert the data into this format.

# %%
from pyspark.sql.types import StructType,StructField,StringType,IntegerType,FloatType
from pyspark.sql.functions import col,to_date,lit,to_timestamp

# %%
schema = StructType(fields=[
    StructField("InvoiceNo",IntegerType(),nullable=False),
    StructField("StockCode",IntegerType(),nullable=True),
    StructField("Description",StringType(),nullable=True),
    StructField("Quantity",IntegerType(),nullable=True),
    StructField("InvoiceDate",StringType(),nullable=True),
    StructField("UnitPrice",FloatType(),nullable=True),
    StructField("CustomerID",IntegerType(),nullable=False),
    StructField("Country",StringType(),nullable=False)
])

# %%
df = spark.read\
    .format("csv")\
    .schema(schema)\
    .option("header",True)\
    .load("dbfs:/FileStore/sales.csv")

# %%
df.show(2,truncate=False)
# Out:
# +---------+---------+----------------------------------+--------+---------------+---------+----------+--------------+
# |InvoiceNo|StockCode|Description                       |Quantity|InvoiceDate    |UnitPrice|CustomerID|Country       |
# +---------+---------+----------------------------------+--------+---------------+---------+----------+--------------+
# |536365   |null     |WHITE HANGING HEART T-LIGHT HOLDER|6       |01-12-2010 8.26|2.55     |17850     |United Kingdom|
# |536365   |71053    |WHITE METAL LANTERN               |6       |01-12-2010 8.26|3.39     |17850     |United Kingdom|
# +---------+---------+----------------------------------+--------+---------------+---------+----------+--------------+
# only showing top 2 rows

# %%
spark.conf.set("spark.sql.legacy.timeParserPolicy","LEGACY")
from pyspark.sql.functions import split,regexp_replace,concat

# %%
df = df.withColumn("InvoiceDate",to_timestamp(col("InvoiceDate"),format="dd-MM-yyyy HH.mm"))

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>Country</th></tr></thead><tbody><tr><td>536365</td><td>null</td><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>2.55</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536365</td><td>71053</td><td>WHITE METAL LANTERN</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536365</td><td>null</td><td>CREAM CUPID HEARTS COAT HANGER</td><td>8</td><td>2010-12-01T08:26:00.000+0000</td><td>2.75</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536365</td><td>null</td><td>KNITTED UNION FLAG HOT WATER BOTTLE</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536365</td><td>null</td><td>RED WOOLLY HOTTIE WHITE HEART.</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>3.39</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536365</td><td>22752</td><td>SET 7 BABUSHKA NESTING BOXES</td><td>2</td><td>2010-12-01T08:26:00.000+0000</td><td>7.65</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536365</td><td>21730</td><td>GLASS STAR FROSTED T-LIGHT HOLDER</td><td>6</td><td>2010-12-01T08:26:00.000+0000</td><td>4.25</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536366</td><td>22633</td><td>HAND WARMER UNION JACK</td><td>6</td><td>2010-12-01T08:28:00.000+0000</td><td>1.85</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536366</td><td>22632</td><td>HAND WARMER RED POLKA DOT</td><td>6</td><td>2010-12-01T08:28:00.000+0000</td><td>1.85</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536367</td><td>84879</td><td>ASSORTED COLOUR BIRD ORNAMENT</td><td>32</td><td>2010-12-01T08:34:00.000+0000</td><td>1.69</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22745</td><td>POPPY'S PLAYHOUSE BEDROOM </td><td>6</td><td>2010-12-01T08:34:00.000+0000</td><td>2.1</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22748</td><td>POPPY'S PLAYHOUSE KITCHEN</td><td>6</td><td>2010-12-01T08:34:00.000+0000</td><td>2.1</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22749</td><td>FELTCRAFT PRINCESS CHARLOTTE DOLL</td><td>8</td><td>2010-12-01T08:34:00.000+0000</td><td>3.75</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22310</td><td>IVORY KNITTED MUG COSY </td><td>6</td><td>2010-12-01T08:34:00.000+0000</td><td>1.65</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>84969</td><td>BOX OF 6 ASSORTED COLOUR TEASPOONS</td><td>6</td><td>2010-12-01T08:34:00.000+0000</td><td>4.25</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22623</td><td>BOX OF VINTAGE JIGSAW BLOCKS </td><td>3</td><td>2010-12-01T08:34:00.000+0000</td><td>4.95</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22622</td><td>BOX OF VINTAGE ALPHABET BLOCKS</td><td>2</td><td>2010-12-01T08:34:00.000+0000</td><td>9.95</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>21754</td><td>HOME BUILDING BLOCK WORD</td><td>3</td><td>2010-12-01T08:34:00.000+0000</td><td>5.95</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>21755</td><td>LOVE BUILDING BLOCK WORD</td><td>3</td><td>2010-12-01T08:34:00.000+0000</td><td>5.95</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>21777</td><td>RECIPE BOX WITH METAL HEART</td><td>4</td><td>2010-12-01T08:34:00.000+0000</td><td>7.95</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>48187</td><td>DOORMAT NEW ENGLAND</td><td>4</td><td>2010-12-01T08:34:00.000+0000</td><td>7.95</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536368</td><td>22960</td><td>JAM MAKING SET WITH JARS</td><td>6</td><td>2010-12-01T08:34:00.000+0000</td><td>4.25 ...

# %%
df.createOrReplaceTempView("SalesTemp")

# %%
# %sql
insert into sales partition(country) select * from SalesTemp;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# #### Read the data from partition

# %%
# %sql
select * from sales where country="France";
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNO</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>Country</th></tr></thead><tbody><tr><td>536370</td><td>22728</td><td>ALARM CLOCK BAKELIKE PINK</td><td>24</td><td>2010-12-01T08:45:00.000+0000</td><td>3.75</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>22727</td><td>ALARM CLOCK BAKELIKE RED </td><td>24</td><td>2010-12-01T08:45:00.000+0000</td><td>3.75</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>22726</td><td>ALARM CLOCK BAKELIKE GREEN</td><td>12</td><td>2010-12-01T08:45:00.000+0000</td><td>3.75</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>21724</td><td>PANDA AND BUNNIES STICKER SHEET</td><td>12</td><td>2010-12-01T08:45:00.000+0000</td><td>0.8500000238418579</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>21883</td><td>STARS GIFT TAPE </td><td>24</td><td>2010-12-01T08:45:00.000+0000</td><td>0.6499999761581421</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>10002</td><td>INFLATABLE POLITICAL GLOBE </td><td>48</td><td>2010-12-01T08:45:00.000+0000</td><td>0.8500000238418579</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>21791</td><td>VINTAGE HEADS AND TAILS CARD GAME </td><td>24</td><td>2010-12-01T08:45:00.000+0000</td><td>1.25</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>21035</td><td>SET/2 RED RETROSPOT TEA TOWELS </td><td>18</td><td>2010-12-01T08:45:00.000+0000</td><td>2.950000047683716</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>22326</td><td>ROUND SNACK BOXES SET OF4 WOODLAND </td><td>24</td><td>2010-12-01T08:45:00.000+0000</td><td>2.950000047683716</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>22629</td><td>SPACEBOY LUNCH BOX </td><td>24</td><td>2010-12-01T08:45:00.000+0000</td><td>1.9500000476837158</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>22659</td><td>LUNCH BOX I LOVE LONDON</td><td>24</td><td>2010-12-01T08:45:00.000+0000</td><td>1.9500000476837158</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>22631</td><td>CIRCUS PARADE LUNCH BOX </td><td>24</td><td>2010-12-01T08:45:00.000+0000</td><td>1.9500000476837158</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>22661</td><td>CHARLOTTE BAG DOLLY GIRL DESIGN</td><td>20</td><td>2010-12-01T08:45:00.000+0000</td><td>0.8500000238418579</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>21731</td><td>RED TOADSTOOL LED NIGHT LIGHT</td><td>24</td><td>2010-12-01T08:45:00.000+0000</td><td>1.649999976158142</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>22900</td><td> SET 2 TEA TOWELS I LOVE LONDON </td><td>24</td><td>2010-12-01T08:45:00.000+0000</td><td>2.950000047683716</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>21913</td><td>VINTAGE SEASIDE JIGSAW PUZZLES</td><td>12</td><td>2010-12-01T08:45:00.000+0000</td><td>3.75</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>22540</td><td>MINI JIGSAW CIRCUS PARADE </td><td>24</td><td>2010-12-01T08:45:00.000+0000</td><td>0.41999998688697815</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>22544</td><td>MINI JIGSAW SPACEBOY</td><td>24</td><td>2010-12-01T08:45:00.000+0000</td><td>0.41999998688697815</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>22492</td><td>MINI PAINT SET VINTAGE </td><td>36</td><td>2010-12-01T08:45:00.000+0000</td><td>0.6499999761581421</td><td>12583</td><td>France</td></tr><tr><td>536370</td><td>null</td><td>POSTAGE</td><td>3</td><td>2010-12-01T08:45:00.000+0000</td><td>18.0</td><td>12583</td><td>France</td></tr><tr><td>536852</td><td>22549</td><td>PICTURE DOMINOES</td><td>12</td><td>2010-12-03T09:51:00.000+0000</td><td>1.4500000476837158</td><td>12686</td><td>France</td></tr><tr><td>536852</td><td>22544</td><td>MINI JIGSAW SPACEBOY</td><td>24</td><td>2010-12-03T09:51:00.000+0000< ...

# %% [markdown]
# #### Bucketing in Hive

# %%
# %sql
drop table if exists sales_bucket; 
CREATE TABLE sales_bucket(
 InvoiceNO          int         comment 'Invoice No',
 StockCode          int         comment 'Stock Code means product Id', 
 Description        string      comment 'Description',
 Quantity           int         comment 'Quantity of a product ordered in invoice',
 InvoiceDate        timestamp   comment 'Invoice Date',
 UnitPrice          double      comment 'Unit Price',
 CustomerID         int         comment 'Customer ID'
)
PARTITIONED BY (Country string)
CLUSTERED BY(CustomerID) INTO 5 BUCKETS
ROW FORMAT DELIMITED FIELDS TERMINATED BY ','
LINES TERMINATED BY '\n'
STORED AS TEXTFILE
LOCATION '/user/hive/warehouse/sharmatrilok.db/src';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
insert into sales_bucket partition(Country)  Select * from SalesTemp;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
describe extended sales_bucket;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>InvoiceNO</td><td>int</td><td>Invoice No</td></tr><tr><td>StockCode</td><td>int</td><td>Stock Code means product Id</td></tr><tr><td>Description</td><td>string</td><td>Description</td></tr><tr><td>Quantity</td><td>int</td><td>Quantity of a product ordered in invoice</td></tr><tr><td>InvoiceDate</td><td>timestamp</td><td>Invoice Date</td></tr><tr><td>UnitPrice</td><td>double</td><td>Unit Price</td></tr><tr><td>CustomerID</td><td>int</td><td>Customer ID</td></tr><tr><td>Country</td><td>string</td><td>null</td></tr><tr><td># Partition Information</td><td></td><td></td></tr><tr><td># col_name</td><td>data_type</td><td>comment</td></tr><tr><td>Country</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Database</td><td>sharmatrilok</td><td></td></tr><tr><td>Table</td><td>sales_bucket</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Created Time</td><td>Wed Dec 07 07:40:29 UTC 2022</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.2.1</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Provider</td><td>hive</td><td></td></tr><tr><td>Num Buckets</td><td>5</td><td></td></tr><tr><td>Bucket Columns</td><td>[`CustomerID`]</td><td></td></tr><tr><td>Sort Columns</td><td>[]</td><td></td></tr><tr><td>Table Properties</td><td>[transient_lastDdlTime=1670398829]</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/hive/warehouse/sharmatrilok.db/src</td><td></td></tr><tr><td>Serde Library</td><td>org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe</td><td></td></tr><tr><td>InputFormat</td><td>org.apache.hadoop.mapred.TextInputFormat</td><td></td></tr><tr><td>OutputFormat</td><td>org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat</td><td></td></tr><tr><td>Storage Properties</td><td>[line.delim=
# , field.delim=,, serialization.format=,]</td><td></td></tr><tr><td>Partition Provider</td><td>Catalog</td><td></td></tr></tbody></table></div>
